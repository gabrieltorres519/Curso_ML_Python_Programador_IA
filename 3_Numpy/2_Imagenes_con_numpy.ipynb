# %% [markdown]
# # Manejando imágenes con Numpy

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
# Cargando la imagen a un Numpy array

array_carro = plt.imread('car_c.jpg')
array_carro.shape # Filas, Columnas, Capas
# Out:
# (100, 188, 3)

# %%
# Visualizamos la imagen

plt.imshow(array_carro, interpolation="nearest") # Interpolación nearest para que pueda aplicar los colores correctos y visualizarlos

# %%
# Extrayendo una de las capas de la imágen

capa_rojo = array_carro[:,:,0]
plt.imshow(capa_rojo, cmap=plt.cm.Reds_r) # Tenemos que indicar que lo que se envía es una capa de color, para que los valores o intensidades
                                          # se interpreten como intensidades de rojo

# %%
# Extrayendo una de las capas de la imágen

capa_verde = array_carro[:,:,1]
plt.imshow(capa_verde, cmap=plt.cm.Greens_r) # Tenemos que indicar que lo que se envía es una capa de color, para que los valores o intensidades
                                          # se interpreten como intensidades de verde

# %%
# Extrayendo una de las capas de la imágen

capa_azul = array_carro[:,:,1]
plt.imshow(capa_azul, cmap=plt.cm.Blues_r) # Tenemos que indicar que lo que se envía es una capa de color, para que los valores o intensidades
                                          # se interpreten como intensidades de azul

# %%
# Vemos que las capas solo tienen dos dimenciones
capa_azul.shape
# Out:
# (100, 188)
