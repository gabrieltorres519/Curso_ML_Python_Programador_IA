# %% [markdown]
# # Redes Neuronales Regresión

# %% [markdown]
# Recordar que en regresión la variable a encontrar es un valor numérico contínuo:
#
# Hasta el momento se han utilizado algoritmos probabilísticos como Naive Bayes o geompetricos como las máquinas de soporte vectorial.
#
# La red neuronal busca imitar una red de neuronas.
#
# Tensorflow es una librería en python, creada por google, que nos permitirá crear, configurar y entrenar nuestra red neuronal, es el equivalente a Sklearn para los algoritmos de machine learning.
#
# Tenemos también pythorch de facebook.
#
# En el siguiente enlace se encuentra una web donde podemos visualizar la arquitectura de una red neuronal, que es la cantidad de capas ocultas y la cantidad de neuronas en cada capa:
#
# https://playground.tensorflow.org/#activation=tanh&batchSize=10&dataset=circle&regDataset=reg-plane&learningRate=0.03&regularizationRate=0&noise=0&networkShape=4,2&seed=0.62109&showTestData=false&discretize=false&percTrainData=50&x=true&y=true&xTimesY=false&xSquared=false&ySquared=false&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=classification&initZero=false&hideText=false

# %% [markdown]
# ![image.png](attachment:image.png)
#
# En la imagen se observan las entradas de las neuronas, los pesos en la red neuronal siempre inician con valores random, en la neurona se realiza una suma de los valores junto con un valor de bias y la activación se da por una función específica que genera la salida de la neurona.
#
# Las redes neuronales son el inicio del deep learning, el deep learnig se encuentra contenido dentro del machine learning.
#
# A diferencia de los pesos, la función de activación sí la definimos nosotros, por lo general esa función de activación es el optimizador que nos va a ayudar a encontrar los pesos adecuados para nuestro problema (que al inicio son aleatorios) y tenemos que probar diferentes funciones dependiendo de nuestro problema.
#
# Algunas funciones de activación son las siguientes:
#
# - Relu: Funciona muy bien para clasificación de imágenes
# - Lineal: Para una regresión lineal
#
# Estas funciones las configuraremos, definiremos y probaremos, todo es prueba y error.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Se puede resumir en que las redes neuronales buscan encontrar los pesos adecuados.
#
# Para éste ejemplo se utilizará el siguiente dataset: https://github.com/stedy/Machine-Learning-with-R-datasets/blob/master/insurance.csv
#
# Se hará una regresión para encontrar la prima del seguro (charges) dados valores de una persona.

# %%
import pandas as pd 
import matplotlib.pyplot as plt 

df = pd.read_csv('https://raw.githubusercontent.com/stedy/Machine-Learning-with-R-datasets/master/insurance.csv')
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# ## 1. Preprocesamiento
